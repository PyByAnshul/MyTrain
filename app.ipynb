# %%
import requests
def index():

    import requests

    url = "https://irctc1.p.rapidapi.com/api/v1/searchTrain"

    querystring = {"query":"190"}

    headers = {
        "X-RapidAPI-Key": "793a7dc73cmsh5fc4ac4754f7c66p1ca8ebjsn655a0b81d347",
        "X-RapidAPI-Host": "irctc1.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)

    return response.json()

# %%
a=index()
# Out:
# [{'train_num': 9809, 'name': 'Kota - Delhi Hazrat Nizamuddin SpecialFare SF Special', 'train_from': 'KOTA', 'train_to': 'NZM', 'data': {'id': '22524', 'days': {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}, 'to_id': '748', 'classes': ['II', 'SL', '3A', '2A'], 'from_id': '891', 'arriveTime': '04:25 +1 night', 'departTime': '21:10'}}, {'train_num': 9810, 'name': 'Delhi Hazrat Nizamuddin - Kota SpecialFare SF Special', 'train_from': 'NZM', 'train_to': 'KOTA', 'data': {'id': '22525', 'days': {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}, 'to_id': '891', 'classes': ['II', 'SL', '3A', '2A'], 'from_id': '748', 'arriveTime': '13:15 ', 'departTime': '05:15'}}, {'train_num': 12001, 'name': 'Bhopal Habibganj - New Delhi Shatabdi Express', 'train_from': 'HBJ', 'train_to': 'NDLS', 'data': {'id': '1516', 'days': {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}, 'to_id': '664', 'classes': ['CC', 'Ex'], 'from_id': '474', 'arriveTime': '23:30 ', 'departTime': '15:00'}}, {'train_num': 12002, 'name': 'New Delhi - Bhopal Habibganj Shatabdi Express', 'train_from': 'NDLS', 'train_to': 'HBJ', 'data': {'id': '1518', 'days': {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}, 'to_id': '474', 'classes': ['CC', 'Ex'], 'from_id': '664', 'arriveTime': '14:25 ', 'departTime': '06:00'}}, {'train_num': 12003, 'name': 'Lucknow Jn - New Delhi Swarn Shatabdi Express', 'train_from': 'LJN', 'train_to': 'NDLS', 'data': {'id': '1520', 'days': {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}, 'to_id': '664', 'classes': ['CC', 'Ex'], 'from_id': '906', 'arriveTime': '22:15 ', 'departTime': '15:35'}}, {'train_num': 12004, 'name': 'New Delhi - Lucknow Jn Swarn Shatabdi Express', 'train_from': 'NDLS', 'train_to': 'LJN', 'data': {'id': '1521', 'days': {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}, 'to_id': '906', 'classes': ['CC', 'Ex'], 'from_id': '664', 'arriveTime': '12:40 ', 'departTime': '06:10'}}]

# %%
for i in a:
    print(i)
# Out:
# {'train_num': 9809, 'name': 'Kota - Delhi Hazrat Nizamuddin SpecialFare SF Special', 'train_from': 'KOTA', 'train_to': 'NZM', 'data': {'id': '22524', 'days': {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}, 'to_id': '748', 'classes': ['II', 'SL', '3A', '2A'], 'from_id': '891', 'arriveTime': '04:25 +1 night', 'departTime': '21:10'}}
# {'train_num': 9810, 'name': 'Delhi Hazrat Nizamuddin - Kota SpecialFare SF Special', 'train_from': 'NZM', 'train_to': 'KOTA', 'data': {'id': '22525', 'days': {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}, 'to_id': '891', 'classes': ['II', 'SL', '3A', '2A'], 'from_id': '748', 'arriveTime': '13:15 ', 'departTime': '05:15'}}
# {'train_num': 12001, 'name': 'Bhopal Habibganj - New Delhi Shatabdi Express', 'train_from': 'HBJ', 'train_to': 'NDLS', 'data': {'id': '1516', 'days': {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}, 'to_id': '664', 'classes': ['CC', 'Ex'], 'from_id': '474', 'arriveTime': '23:30 ', 'departTime': '15:00'}}
# {'train_num': 12002, 'name': 'New Delhi - Bhopal Habibganj Shatabdi Express', 'train_from': 'NDLS', 'train_to': 'HBJ', 'data': {'id': '1518', 'days': {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}, 'to_id': '474', 'classes': ['CC', 'Ex'], 'from_id': '664', 'arriveTime': '14:25 ', 'departTime': '06:00'}}
# {'train_num': 12003, 'name': 'Lucknow Jn - New Delhi Swarn Shatabdi Express', 'train_from': 'LJN', 'train_to': 'NDLS', 'data': {'id': '1520', 'days': {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}, 'to_id': '664', 'classes': ['CC', 'Ex'], 'from_id': '906', 'arriveTime': '22:15 ', 'departTime': '15:35'}}
# {'train_num': 12004, 'name': 'New Delhi - Lucknow Jn Swarn Shatabdi Express', 'train_from': 'NDLS', 'train_to': 'LJN', 'data': {'id': '1521', 'days': {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}, 'to_id': '906', 'classes': ['CC', 'Ex'], 'from_id': '664', 'arriveTime': '12:40 ', 'departTime': '06:10'}}

# %%
import pandas as pd

# %%
df=pd.read_csv('data/Train_details_22122017.csv')
# Out:
# C:\Users\a9756\AppData\Local\Temp\ipykernel_22072\3639063885.py:1: DtypeWarning: Columns (0,2,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('data/Train_details_22122017.csv')

# %%
a=list(df['Station Name'])

# %%
import json
with open('a.json','w') as file:
    file.write(json.dumps(a))

# %%
# Out:
# ['SAWANTWADI R',
#  'THIVIM',
#  'KARMALI',
#  'MADGOAN JN.',
#  'MADGOAN JN.',
#  'KARMALI',
#  'THIVIM',
#  'SAWANTWADI R',
#  'MADGOAN JN.',
#  'KARMALI',
#  'THIVIM',
#  'SAWANTWADI R',
#  'KUDAL',
#  'SINDHU DURG',
#  'KANKAVALI',
#  'VAIBHAVWADI',
#  'RAJAPUR ROAD',
#  'RATNAGIRI',
#  'SANGMESHWAR',
#  'CHIPLUN',
#  'KHED',
#  'MANGAON',
#  'ROHA',
#  'PANVEL',
#  'KARJAT',
#  'LONAVLA',
#  'PUNE JN.',
#  'SATARA',
#  'MIRAJ JN.',
#  'CHHATRAPATI',
#  'DELHI-SAFDAR',
#  'GANDHINAGAR',
#  'JAIPUR JN.',
#  'DURGAPURA',
#  'SAWAI MADHOP',
#  'CHITTAURGARH',
#  'UDAIPUR CITY',
#  'JAISALMER',
#  'MANDOR',
#  'PHULERA JN.',
#  'BHARATPUR JN',
#  'IDGAH',
#  'AGRA CANTT',
#  'DELHI-SAFDAR',
#  'AURANGABAD',
#  'MANMAD JN.',
#  'BHUSAVAL JN.',
#  'KHANDWA JN.',
#  'JHANSI JN',
#  'KANPUR CENTR',
#  'LUCKNOW JN.',
#  'BARA BANKI J',
#  'AYODHYA',
#  'SHAHGANJ JN.',
#  'JAUNPUR JN.',
#  'VARANASI JN.',
#  'LUCKNOW JN.',
#  'FATEHGARH',
#  'KASGANJ JN.',
#  'BAREILLY JN.',
#  'SHRI MATA VA',
#  'SHRI MATA VA',
#  'BAREILLY JN.',
#  'KASGANJ JN.',
#  'FATEHGARH',
#  'LUCKNOW JN.',
#  'SIRSA',
#  'HISAR JN',
#  'BHIWANI JN.',
#  'ROHTAK JN.',
#  'DELHI-SAFDAR',
#  'KANPUR CENTR',
#  'MUGHAL SARAI',
#  'MUGHAL SARAI',
#  'KANPUR CENTR',
#  'DELHI-SAFDAR',
#  'ROHTAK JN.',
#  'BHIWANI JN.',
#  'HISAR JN',
#  'SIRSA',
#  'RAJENDRANAGA',
#  'MUGHAL SARAI',
#  'KANPUR CENTR',
#  'DELHI-SAFDAR',
#  'SONIPAT',
#  'PANIPAT JN.',
#  'KARNAL',
#  'KURUKSHETRA',
#  'AMBALA CANTT',
#  'PATNA JN.',
#  'MUGHAL SARAI',
#  'BATHINDA JN',
#  'PATNA JN.',
#  'MUGHAL SARAI',
#  'PATIALA',
#  'URKURA',
#  'PANJIPARA',
#  'PATNA JN.',
#  'MUGHAL SARAI',
#  'AMRITSAR JN.',
#  'CST-MUMBAI',
#  'DADAR',
#  'THANE',
#  'KALYAN JN',
#  'IGATPURI',
#  'NASIK ROAD',
#  'MANMAD JN.',
#  'JALGAON JN.',
#  'BHUSAVAL JN.',
#  'MALKAPUR',
#  'SHEGAON',
#  'AKOLA JN.',
#  'MURTAJAPUR J',
#  'BADNERA JN.',
#  'DHAMANGAON',
#  'PULGAON JN.',
#  'WARDHA JN.',
#  'NAGPUR JN.(C',
#  'LOKMANYA TIL',
#  'THANE',
#  'PANVEL',
#  'ROHA',
#  'KHED',
#  'CHIPLUN',
#  'RATNAGIRI',
#  'KANKAVALI',
#  'KUDAL',
#  'SAWANTWADI R',
#  'SAWANTWADI R',
#  'KUDAL',
#  'KANKAVALI',
#  'RATNAGIRI',
#  'CHIPLUN',
#  'KHED',
#  'ROHA',
#  'PANVEL',
#  'THANE',
#  'LOKMANYA TIL',
#  'LOKMANYA TIL',
#  'THANE',
#  'PANVEL',
#  'ROHA',
#  'KHED',
#  'CHIPLUN',
#  'RATNAGIRI',
#  'KANKAVALI',
#  'KUDAL',
#  'THIVIM',
#  'KARMALI',
#  'AJNI',
#  'WARDHA JN.',
#  'PULGAON JN.',
#  'DHAMANGAON',
#  'BADNERA JN.',
#  'AKOLA JN.',
#  'SHEGAON',
#  'MALKAPUR',
#  'BHUSAVAL JN.',
#  'JALGAON JN.',
#  'CHALISGAON J',
#  'MANMAD JN.',
#  'NASIK ROAD',
#  'IGATPURI',
#  'KALYAN JN',
#  'PANVEL',
#  'ROHA',
#  'KHED',
#  'CHIPLUN',
#  'RATNAGIRI',
#  'KANKAVALI',
#  'KUDAL',
#  'THIVIM',
#  'KARMALI',
#  'KARMALI',
#  'THIVIM',
#  'KUDAL',
#  'KANKAVALI',
#  'RATNAGIRI',
#  'CHIPLUN',
#  'KHED',
#  'ROHA',
#  'PANVEL',
#  'KALYAN JN',
#  'IGATPURI',
#  'NASIK ROAD',
#  'MANMAD JN.',
#  'CHALISGAON J',
#  'JALGAON JN.',
#  'BHUSAVAL JN.',
#  'MALKAPUR',
#  'SHEGAON',
#  'AKOLA JN.',
#  'BADNERA JN.',
#  'DHAMANGAON',
#  'PULGAON JN.',
#  'WARDHA JN.',
#  'AJNI',
#  'KARMALI',
#  'THIVIM',
#  'SAWANTWADI R',
#  'KUDAL',
#  'KANKAVALI',
#  'RATNAGIRI',
#  'SANGMESHWAR',
#  'CHIPLUN',
#  'KHED',
#  'ROHA',
#  'PANVEL',
#  'THANE',
#  'DADAR',
#  'CST-MUMBAI',
#  'NAGPUR JN.(C',
#  'WARDHA JN.',
#  'PULGAON JN.',
#  'DHAMANGAON',
#  'BADNERA JN.',
#  'AKOLA JN.',
#  'SHEGAON',
#  'MALKAPUR',
#  'BHUSAVAL JN.',
#  'JALGAON JN.',
#  'CHALISGAON J',
#  'MANMAD JN.',
#  'NASIK ROAD',
#  'IGATPURI',
#  'KALYAN JN',
#  'PANVEL',
#  'ROHA',
#  'KHED',
#  'CHIPLUN',
#  'SANGMESHWAR',
#  'RATNAGIRI',
#  'KANKAVALI',
#  'KUDAL',
#  'SAWANTWADI R',
#  'THIVIM',
#  'KARMALI',
#  'PUNE JN.',
#  'LONAVLA',
#  'PANVEL',
#  'ROHA',
#  'KHED',
#  'CHIPLUN',
#  'RATNAGIRI',
#  'KANKAVALI',
#  'KUDAL',
#  'THIVIM',
#  'MADGOAN JN.',
#  'KAWR',
#  'KUMTA',
#  'KUNDAPURA',
#  'UDUPI',
#  'MULKI',
#  'MANGALORE JN',
#  'MANGALORE JN',
#  'MULKI',
#  'UDUPI',
#  'KUNDAPURA',
#  'KUMTA',
#  'KAWR',
#  'MADGOAN JN.',
#  'THIVIM',
#  'KUDAL',
#  'KANKAVALI',
#  'RATNAGIRI',
#  'CHIPLUN',
#  'KHED',
#  'ROHA',
#  'PANVEL',
#  'LONAVLA',
#  'PUNE JN.',
#  'DELHI-SAFDAR',
#  'MATHURA JN.',
#  'AGRA CANTT',
#  'GWALIOR JN',
#  'JHANSI JN',
#  'BHOPAL',
#  'ITARSI',
#  'KHANDWA JN.',
#  'BHUSAVAL JN.',
#  'MANMAD JN.',
#  'DAUND JN.',
#  'PUNE JN.',
#  'KHADKI',
#  'PUNE JN.',
#  'DAUND JN.',
#  'AHMADNAGAR',
#  'KOPARGAON',
#  'MANMAD JN.',
#  'BHUSAVAL JN.',
#  'KHANDWA JN.',
#  'HARDA',
#  'ITARSI',
#  'PIPARIYA',
#  'NARSINGHPUR',
#  'MADANMAHAL',
#  'JABALPUR',
#  'JABALPUR',
#  'MADANMAHAL',
#  'NARSINGHPUR',
#  'PIPARIYA',
#  'ITARSI',
#  'HARDA',
#  'KHANDWA JN.',
#  'BHUSAVAL JN.',
#  'MANMAD JN.',
#  'KOPARGAON',
#  'AHMADNAGAR',
#  'DAUND JN.',
#  'PUNE JN.',
#  'BANDRA TERMI',
#  'BORIVLI',
#  'VAPI',
#  'SURAT',
#  'VADODARA JN.',
#  'RATLAM JN',
#  'UJJAIN JN',
#  'BAIRAGARH',
#  'BHOPAL',
#  'HOSHANGABAD',
#  'ITARSI',
#  'PIPARIYA',
#  'NARSINGHPUR',
#  'JABALPUR',
#  'JABALPUR',
#  'NARSINGHPUR',
#  'PIPARIYA',
#  'ITARSI',
#  'HOSHANGABAD',
#  'BHOPAL',
#  'BAIRAGARH',
#  'UJJAIN JN',
#  'RATLAM JN',
#  'VADODARA JN.',
#  'SURAT',
#  'VAPI',
#  'BORIVLI',
#  'BANDRA TERMI',
#  'JABALPUR',
#  'KATNI MURWAR',
#  'DAMOH',
#  'SAUGOR',
#  'MALKHEDI',
#  'LALITPUR',
#  'JHANSI JN',
#  'GWALIOR JN',
#  'AGRA CANTT',
#  'MATHURA JN.',
#  'NEW DELHI',
#  'AMBALA CANTT',
#  'LUDHIANA JN.',
#  'JALANDHAR CI',
#  'BEAS JN',
#  'AMRITSAR JN.',
#  'ATARI JN',
#  'ATARI JN',
#  'AMRITSAR JN.',
#  'BEAS JN',
#  'JALANDHAR CI',
#  'LUDHIANA JN.',
#  'AMBALA CANTT',
#  'NEW DELHI',
#  'MATHURA JN.',
#  'AGRA CANTT',
#  'GWALIOR JN',
#  'JHANSI JN',
#  'LALITPUR',
#  'MALKHEDI',
#  'SAUGOR',
#  'DAMOH',
#  'KATNI MURWAR',
#  'JABALPUR',
#  'CST-MUMBAI',
#  'DADAR',
#  'THANE',
#  'PANVEL',
#  'RATNAGIRI',
#  'KUDAL',
#  'KARMALI',
#  'KARMALI',
#  'KUDAL',
#  'RATNAGIRI',
#  'PANVEL',
#  'THANE',
#  'DADAR',
#  'CST-MUMBAI',
#  'JABALPUR',
#  'SIHORAROAD',
#  'KATNI',
#  'UMARIA',
#  'SHAHDOL',
#  'ANUPPUR JN.',
#  'PENDRA ROAD',
#  'BILASPUR JN.',
#  'CHAMPA JN.',
#  'RAIGARH',
#  'JHARSUGUDA J',
#  'ROURKELA',
#  'CHAKARADHARP',
#  'TATANAGAR JN',
#  'KHARAGPUR',
#  'SANTRAGACHI',
#  'SANTRAGACHI',
#  'KHARAGPUR',
#  'TATANAGAR JN',
#  'CHAKARADHARP',
#  'ROURKELA',
#  'JHARSUGUDA J',
#  'RAIGARH',
#  'CHAMPA JN.',
#  'BILASPUR JN.',
#  'PENDRA ROAD',
#  'ANUPPUR JN.',
#  'SHAHDOL',
#  'UMARIA',
#  'KATNI',
#  'SIHORAROAD',
#  'JABALPUR',
#  'REWA',
#  'SATNA',
#  'MAIHAR',
#  'JUKEHI',
#  'KATNI',
#  'DAMOH',
#  'SAUGOR',
#  'BINA',
#  'VIDISHA',
#  'BHOPAL',
#  'BHOPAL',
#  'VIDISHA',
#  'BINA',
#  'SAUGOR',
#  'DAMOH',
#  'KATNI',
#  'JUKEHI',
#  'MAIHAR',
#  'SATNA',
#  'REWA',
#  'TRIVANDRUM C',
#  'QUILON',
#  'KAYANKULAM J',
#  'MAVELIKARA',
#  'CHENGANNUR',
#  'TIRUVALLA',
#  'KOTTAYAM',
#  'ERNAKULAM TO',
#  'ALWAYE',
#  'TRICHUR',
#  'PALAKKAD JN',
#  'COIMBATORE',
#  'TIRUPPUR',
#  'ERODE JN.',
#  'SALEM JN.',
#  'JOLARPETTAI',
#  'KATPADI JN',
#  'ARAKKONAM JN',
#  'CHENNAI CENT',
#  'ONGOLE',
#  'VIJAYWADA JN',
#  'RAJAHMUNDRY',
#  'VISAKHAPATNA',
#  'VIZIANAGARAM',
#  'SRIKAKULAM R',
#  'PALASA',
#  'BERHAMPUR',
#  'BALUGAN',
#  'KHURDA ROAD',
#  'BHUBANESWAR',
#  'CUTTACK JN.',
#  'JAJPUR KEONJ',
#  'BHADRAKH',
#  'BALASORE',
#  'KHARAGPUR',
#  'SANTRAGACHI',
#  'HOWRAH JN.',
#  'BOLPUR',
#  'RAMPUR HAT',
#  'PAKUR',
#  'NEW FARAKKA',
#  'MALDA TOWN',
#  'KISHANGANJ',
#  'NEW JALPAIGU',
#  'DHUPGURI',
#  'NEW COOCH BE',
#  'NEW ALIPURDU',
#  'KOKRAJHAR',
#  'NEW BONGAIGA',
#  'BARPETA ROAD',
#  'RANGIYA JN.',
#  'KAMAKHYA JN',
#  'GUWAHATI',
#  'HOJAI',
#  'LUMDING JN.',
#  'NEW HARANGAJ',
#  'BADARPUR JN.',
#  'SILCHAR',
#  'PALANI',
#  'UDUMALAIPPET',
#  'POLLACHI',
#  'POLLACHI',
#  'UDUMALAIPPET',
#  'PALANI',
#  'HYDERABAD DE',
#  'SECUNDERABAD',
#  'MEDCHAL',
#  'KAMAREDDI',
#  'NIZAMABAD',
#  'DHARMABAD',
#  'MUDKHED JN.',
#  'NANDED',
#  'PURNA  JN.',
#  'BASMAT',
#  'HINGOLI(DECC',
#  'WASHIM',
#  'AKOLA JN.',
#  'MALKAPUR',
#  'BURHANPUR',
#  'KHANDWA JN.',
#  'ITARSI',
#  'BHOPAL',
#  'UJJAIN JN',
#  'NAGDA JN',
#  'RATLAM JN',
#  'MANDSOR',
#  'NIMACH',
#  'CHITTAURGARH',
#  'BHILWARA',
#  'AJMER JN.',
#  'KISHANGARH',
#  'PHULERA JN.',
#  'JAIPUR JN.',
#  'JAIPUR JN.',
#  'PHULERA JN.',
#  'KISHANGARH',
#  'AJMER JN.',
#  'BHILWARA',
#  'CHITTAURGARH',
#  'NIMACH',
#  'MANDSOR',
#  'RATLAM JN',
#  'NAGDA JN',
#  'UJJAIN JN',
#  'BHOPAL',
#  'ITARSI',
#  'KHANDWA JN.',
#  'BURHANPUR',
#  'MALKAPUR',
#  'AKOLA JN.',
#  'WASHIM',
#  'HINGOLI(DECC',
#  'BASMAT',
#  'PURNA  JN.',
#  'NANDED',
#  'MUDKHED JN.',
#  'DHARMABAD',
#  'NIZAMABAD',
#  'KAMAREDDI',
#  'MEDCHAL',
#  'SECUNDERABAD',
#  'HYDERABAD DE',
#  'PUNE JN.',
#  'PANVEL',
#  'KALYAN JN',
#  'BHUSAVAL JN.',
#  'NAGPUR JN.(C',
#  'DURG',
#  'RAIPUR JN.',
#  'BILASPUR JN.',
#  'JHARSUGUDA J',
#  'ROURKELA',
#  'CHAKARADHARP',
#  'TATANAGAR JN',
#  'KHARAGPUR',
#  'SANTRAGACHI',
#  'SANTRAGACHI',
#  'KHARAGPUR',
#  'TATANAGAR JN',
#  'CHAKARADHARP',
#  'ROURKELA',
#  'JHARSUGUDA J',
#  'BILASPUR JN.',
#  'RAIPUR JN.',
#  'DURG',
#  'NAGPUR JN.(C',
#  'BHUSAVAL JN.',
#  'KALYAN JN',
#  'PANVEL',
#  'PUNE JN.',
#  'RAJKOT',
#  'WANKANER',
#  'SURENDRANAGA',
#  'VIRAMGAM JN',
#  'AHMEDABAD',
#  'NADIAD JN.',
#  'ANAND JN.',
#  'VADODARA JN.',
#  'BHARUCH JN.',
#  'SURAT',
#  'NANDURBAR',
#  'AMALNER',
#  'JALGAON JN.',
#  'BHUSAVAL JN.',
#  'MALKAPUR',
#  'AKOLA JN.',
#  'BADNERA JN.',
#  'WARDHA JN.',
#  'NAGPUR JN.(C',
#  'GONDIA JN.',
#  'DURG',
#  'RAIPUR JN.',
#  'BILASPUR JN.',
#  'JHARSUGUDA J',
#  'ROURKELA',
#  'CHAKARADHARP',
#  'TATANAGAR JN',
#  'KHARAGPUR',
#  'SANTRAGACHI',
#  'SANTRAGACHI',
#  'KHARAGPUR',
#  'TATANAGAR JN',
#  'CHAKARADHARP',
#  'ROURKELA',
#  'JHARSUGUDA J',
#  'BILASPUR JN.',
#  'RAIPUR JN.',
#  'DURG',
#  'GONDIA JN.',
#  'NAGPUR JN.(C',
#  'WARDHA JN.',
#  'BADNERA JN.',
#  'AKOLA JN.',
#  'MALKAPUR',
#  'BHUSAVAL JN.',
#  'JALGAON JN.',
#  'AMALNER',
#  'NANDURBAR',
#  'SURAT',
#  'BHARUCH JN.',
#  'VADODARA JN.',
#  'ANAND JN.',
#  'NADIAD JN.',
#  'AHMEDABAD',
#  'VIRAMGAM JN',
#  'SURENDRANAGA',
#  'WANKANER',
#  'RAJKOT',
#  'SANTRAGACHI',
#  'KHARAGPUR',
#  'BHADRAKH',
#  'CUTTACK JN.',
#  'BHUBANESWAR',
#  'KHURDA ROAD',
#  'VISAKHAPATNA',
#  'DUVVADA',
#  'RAJAHMUNDRY',
#  'VIJAYWADA JN',
#  'NELLORE',
#  'CHENNAI CENT',
#  'CHENNAI CENT',
#  'NELLORE',
#  'VIJAYWADA JN',
#  'RAJAHMUNDRY',
#  'DUVVADA',
#  'VISAKHAPATNA',
#  'KHURDA ROAD',
#  'BHUBANESWAR',
#  'CUTTACK JN.',
#  'BHADRAKH',
#  'KHARAGPUR',
#  'SANTRAGACHI',
#  'PUNE JN.',
#  'DAUND JN.',
#  'AHMADNAGAR',
#  'KOPARGAON',
#  'MANMAD JN.',
#  'BHUSAVAL JN.',
#  'AKOLA JN.',
#  'BADNERA JN.',
#  'WARDHA JN.',
#  'NAGPUR JN.(C',
#  'GONDIA JN.',
#  'DURG',
#  'RAIPUR JN.',
#  'BILASPUR JN.',
#  'JHARSUGUDA J',
#  'ROURKELA',
#  'HATIA',
#  'HATIA',
#  'ROURKELA',
#  'JHARSUGUDA J',
#  'BILASPUR JN.',
#  'RAIPUR JN.',
#  'DURG',
#  'GONDIA JN.',
#  'NAGPUR JN.(C',
#  'WARDHA JN.',
#  'BADNERA JN.',
#  'AKOLA JN.',
#  'BHUSAVAL JN.',
#  'MANMAD JN.',
#  'KOPARGAON',
#  'AHMADNAGAR',
#  'DAUND JN.',
#  'PUNE JN.',
#  'KOLKATA',
#  'KHARAGPUR',
#  'BALASORE',
#  'BHADRAKH',
#  'JAJPUR KEONJ',
#  'CUTTACK JN.',
#  'BHUBANESWAR',
#  'KHURDA ROAD',
#  'PURI',
#  'PURI',
#  'KHURDA ROAD',
#  'BHUBANESWAR',
#  'CUTTACK JN.',
#  'JAJPUR KEONJ',
#  'BHADRAKH',
#  'BALASORE',
#  'KHARAGPUR',
#  'KOLKATA',
#  'ASANSOL MAIN',
#  'BARACHAK JN.',
#  'SITARAMPUR J',
#  'KULTI',
#  'BARAKAR',
#  'KUMAR DUBI',
#  'MUGMA',
#  'THANPAR NAGA',
#  'KALUBATHAN',
#  'CHHOTA AMBAN',
#  'PRADHAN KHUN',
#  'DOKRA HALT',
#  'DHANBAD JN.',
#  'DHANBAD JN.',
#  'DOKRA HALT',
#  'PRADHAN KHUN',
#  'CHHOTA AMBAN',
#  'KALUBATHAN',
#  'THANPAR NAGA',
#  'MUGMA',
#  'KUMAR DUBI',
#  'BARAKAR',
#  'KULTI',
#  'SITARAMPUR J',
#  'BARACHAK JN.',
#  'ASANSOL MAIN',
#  'DHANBAD JN.',
#  'KUSUNDA',
#  'KUSUNDA',
#  'DHANBAD JN.',
#  'SONARDIH',
#  'TUNDU',
#  'BUDORA',
#  'PHULWARTANR',
#  'PHULWARTANR',
#  'BUDORA',
#  'TUNDU',
#  'SONARDIH',
#  'JASIDIH JN.',
#  'PATNA JN.',
#  'MUGHAL SARAI',
#  'KANPUR CENTR',
#  'ANAND VIHAR',
#  'ANAND VIHAR',
#  'KANPUR CENTR',
#  'MUGHAL SARAI',
#  'PATNA JN.',
#  'JASIDIH JN.',
#  'ANAND VIHAR',
#  'GHAZIABAD JN',
#  'MEERUT CITY',
#  'MUZAFFARNAGA',
#  'SAHARANPUR J',
#  'YAMUNANAGER',
#  'AMBALA CANTT',
#  'LUDHIANA JN.',
#  'JALANDHAR CA',
#  'PATHANKOT CA',
#  'JAMMU TAWI',
#  'UDHAMPUR',
#  'SHRI MATA VA',
#  'SHRI MATA VA',
#  'UDHAMPUR',
#  'JAMMU TAWI',
#  'PATHANKOT CA',
#  'JALANDHAR CA',
#  'LUDHIANA JN.',
#  'AMBALA CANTT',
#  'YAMUNANAGER',
#  'SAHARANPUR J',
#  'MUZAFFARNAGA',
#  'MEERUT CITY',
#  'GHAZIABAD JN',
#  'ANAND VIHAR',
#  'DELHI JN.',
#  'AMBALA CANTT',
#  'LUDHIANA JN.',
#  'PATHANKOT CA',
#  'JAMMU TAWI',
#  'UDHAMPUR',
#  'SHRI MATA VA',
#  'SHRI MATA VA',
#  'UDHAMPUR',
#  'JAMMU TAWI',
#  'PATHANKOT CA',
#  'LUDHIANA JN.',
#  'AMBALA CANTT',
#  'DELHI JN.',
#  'MADGOAN JN.',
#  'THIVIM',
#  'KUDAL',
#  'RATNAGIRI',
#  'CHIPLUN',
#  'ROHA',
#  'PANVEL',
#  'VASAI ROAD',
#  'SURAT',
#  'VADODARA JN.',
#  'RATLAM JN',
#  'KOTA',
#  'HAZRAT NIZAM',
#  'HAZRAT NIZAM',
#  'KOTA',
#  'RATLAM JN',
#  'VADODARA JN.',
#  'SURAT',
#  'VASAI ROAD',
#  'PANVEL',
#  'ROHA',
#  'CHIPLUN',
#  'RATNAGIRI',
#  'KUDAL',
#  'THIVIM',
#  'MADGOAN JN.',
#  'BIKANER JN.',
#  'NAPASAR',
#  'SUDSAR',
#  'SRI DUNGARGA',
#  'RAJALDESAR',
#  'RATANAGARH J',
#  'CHURU',
#  'SADULPUR JN',
#  'LOHARU JN',
#  'MAHENDRAGARH',
#  'REWARI JN.',
#  'DELHI JN.',
#  'DELHI-SHAHDA',
#  'SHAMLI',
#  'TAPRI JN.',
#  'ROORKEE',
#  'HARIDWAR JN',
#  'HARIDWAR JN',
#  'ROORKEE',
#  'TAPRI JN.',
#  'SHAMLI',
#  'DELHI-SHAHDA',
#  'DELHI JN.',
#  'REWARI JN.',
#  'MAHENDRAGARH',
#  'LOHARU JN',
#  'SADULPUR JN',
#  'CHURU',
#  'RATANAGARH J',
#  'RAJALDESAR',
#  'SRI DUNGARGA',
#  'SUDSAR',
#  'NAPASAR',
#  'BIKANER JN.',
#  'HANUMANGARH',
#  'JORKIAN',
#  'HIRNAWALI',
#  'DHOLIPAL',
#  'BUGLANWALI',
#  'BUDHSINGHWAL',
#  'SADULSHAHAR',
#  'FATEH SINGHW',
#  'BANWALI',
#  'SHRI GANGANA',
#  'SHRI GANGANA',
#  'BANWALI',
#  'FATEH SINGHW',
#  'SADULSHAHAR',
#  'BUDHSINGHWAL',
#  'BUGLANWALI',
#  'DHOLIPAL',
#  'HIRNAWALI',
#  'JORKIAN',
#  'HANUMANGARH',
#  'HANUMANGARH',
#  'JORKIAN',
#  'HIRNAWALI',
#  'DHOLIPAL',
#  'BUGLANWALI',
#  'BUDHSINGHWAL',
#  'SADULSHAHAR',
#  'FATEH SINGHW',
#  'BANWALI',
#  'SHRI GANGANA',
#  'SHRI GANGANA',
#  'BANWALI',
#  'FATEH SINGHW',
#  'SADULSHAHAR',
#  'BUDHSINGHWAL',
#  'BUGLANWALI',
#  'DHOLIPAL',
#  'HIRNAWALI',
#  'JORKIAN',
#  'HANUMANGARH',
#  'SADULPUR JN',
#  'NARWASI',
#  'SIDMUKH',
#  'ANUP SHAHR',
#  'TAHSIL BHADR',
#  'GOGAMERI',
#  'DIPLANA',
#  'NOHAR',
#  'KHINANIYAN',
#  'ELLENABAD',
#  'TALWARA JHIL',
#  'TIBI',
#  'SHEREKAN',
#  'HANUMANGARH',
#  'HANUMANGARH',
#  'JORKIAN',
#  'HIRNAWALI',
#  'DHOLIPAL',
#  'BUGLANWALI',
#  'BUDHSINGHWAL',
#  'SADULSHAHAR',
#  'FATEH SINGHW',
#  'BANWALI',
#  'SHRI GANGANA',
#  'SHRI GANGANA',
#  'BANWALI',
#  'FATEH SINGHW',
#  'SADULSHAHAR',
#  'BUDHSINGHWAL',
#  'BUGLANWALI',
#  'DHOLIPAL',
#  'HIRNAWALI',
#  'JORKIAN',
#  'HANUMANGARH',
#  'HANUMANGARH',
#  'SHEREKAN',
#  'TIBI',
#  'TALWARA JHIL',
#  'ELLENABAD',
#  'KHINANIYAN',
#  'NOHAR',
#  'DIPLANA',
#  'GOGAMERI',
#  'TAHSIL BHADR',
#  'ANUP SHAHR',
#  'SIDMUKH',
#  'NARWASI',
#  'SADULPUR JN',
#  'SHRI GANGANA',
#  'PRITHWIRAJPU',
#  'KESRI SINGHP',
#  'DALPAT SINGH',
#  'SHRI KARANPU',
#  'ZORAWARPURA',
#  'GAJSINGHPUR',
#  'RAI SINGH NA',
#  'MOHAN NAGAR',
#  'MASANIWALA',
#  'BUGIA',
#  'JAITSAR',
#  'SARUPSAR JN.',
#  'SARDARGARH',
#  'BHAGWANSAR',
#  'SURATGARH JN',
#  'SURATGARH JN',
#  'SARDARGARH',
#  'SARUPSAR JN.',
#  'JAITSAR',
#  'MOHAN NAGAR',
#  'RAI SINGH NA',
#  'GAJSINGHPUR',
#  'SHRI KARANPU',
#  'KESRI SINGHP',
#  'SHRI GANGANA',
#  'PARVATSAR CI',
#  'BIDIYAD',
#  'MAKRANA JN.',
#  'MAKRANA JN.',
#  'BIDIYAD',
#  'PARVATSAR CI',
#  'JODHPUR JN.',
#  'GOTAN',
#  'MERTA ROAD J',
#  'DEGANA JN.',
#  'KHATU',
#  'CHHOTI KHATU',
#  'DIDWANA',
#  'LADNUN',
#  'SUJANGARH',
#  'RATANAGARH J',
#  ...]
