# %%
import requests
def index():

    import requests

    url = "https://irctc1.p.rapidapi.com/api/v1/searchTrain"

    querystring = {"query":"190"}

    headers = {
        "X-RapidAPI-Key": "793a7dc73cmsh5fc4ac4754f7c66p1ca8ebjsn655a0b81d347",
        "X-RapidAPI-Host": "irctc1.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)

    return response.json()

# %%
a=index()
# Out:
# [{'train_num': 9809, 'name': 'Kota - Delhi Hazrat Nizamuddin SpecialFare SF Special', 'train_from': 'KOTA', 'train_to': 'NZM', 'data': {'id': '22524', 'days': {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}, 'to_id': '748', 'classes': ['II', 'SL', '3A', '2A'], 'from_id': '891', 'arriveTime': '04:25 +1 night', 'departTime': '21:10'}}, {'train_num': 9810, 'name': 'Delhi Hazrat Nizamuddin - Kota SpecialFare SF Special', 'train_from': 'NZM', 'train_to': 'KOTA', 'data': {'id': '22525', 'days': {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}, 'to_id': '891', 'classes': ['II', 'SL', '3A', '2A'], 'from_id': '748', 'arriveTime': '13:15 ', 'departTime': '05:15'}}, {'train_num': 12001, 'name': 'Bhopal Habibganj - New Delhi Shatabdi Express', 'train_from': 'HBJ', 'train_to': 'NDLS', 'data': {'id': '1516', 'days': {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}, 'to_id': '664', 'classes': ['CC', 'Ex'], 'from_id': '474', 'arriveT
# ...

# %%
for i in a:
    print(i)
# Out:
# {'train_num': 9809, 'name': 'Kota - Delhi Hazrat Nizamuddin SpecialFare SF Special', 'train_from': 'KOTA', 'train_to': 'NZM', 'data': {'id': '22524', 'days': {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}, 'to_id': '748', 'classes': ['II', 'SL', '3A', '2A'], 'from_id': '891', 'arriveTime': '04:25 +1 night', 'departTime': '21:10'}}
# {'train_num': 9810, 'name': 'Delhi Hazrat Nizamuddin - Kota SpecialFare SF Special', 'train_from': 'NZM', 'train_to': 'KOTA', 'data': {'id': '22525', 'days': {'Fri': 1, 'Mon': 1, 'Sat': 1, 'Sun': 1, 'Thu': 1, 'Tue': 1, 'Wed': 1}, 'to_id': '891', 'classes': ['II', 'SL', '3A', '2A'], 'from_id': '748', 'arriveTime': '13:15 ', 'departTime': '05:15'}}
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('data/Train_details_22122017.csv')
df
# Out:
# C:\Users\a9756\AppData\Local\Temp\ipykernel_13480\4012690008.py:1: DtypeWarning: Columns (0,2,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('data/Train_details_22122017.csv')
#        Train No    Train Name SEQ Station Code  Station Name Arrival time  \
# 0           107  SWV-MAO-VLNK   1          SWV  SAWANTWADI R     00:00:00
# 1           107  SWV-MAO-VLNK   2         THVM        THIVIM     11:06:00
# 2           107  SWV-MAO-VLNK   3         KRMI       KARMALI     11:28:00
# 3           107  SWV-MAO-VLNK   4          MAO   MADGOAN JN.     12:10:00
# 4           108  VLNK-MAO-SWV   1          MAO   MADGOAN JN.     00:00:00
# ...         ...           ...  ..          ...           ...          ...
# 186119    99908           EMU   8         AKRD        AKURDI     23:30:00
# 186120    99908           EMU   9         DEHR     DEHU ROAD     23:35:00
# 186121    99908           EMU  10         BGWI     BEGDAEWAI     23:39:00
# ...

# %%
a=list(df['Destination Station Name'])

# %%
import json
with open('a.json','w') as file:
    file.write(json.dumps(a))

# %%
{'status': True, 'message': 'Success', 'timestamp': 1702731338382, 'data': [{'train_number': '14089', 'train_name': 'Anand Vihar T - Kotdwar Express', 'run_days': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'], 'train_src': 'ANVT', 'train_dstn': 'KTW', 'from_std': '21:45', 'from_sta': '21:45', 'local_train_from_sta': 1305, 'to_sta': '23:30', 'to_std': '23:32', 'from_day': 0, 'to_day': 0, 'd_day': 0, 'from': 'ANVT', 'to': 'MOZ', 'from_station_name': 'ANAND VIHAR TRM', 'halt_stn': 3, 'distance': 116, 'to_station_name': 'MUZAFFARNAGAR', 'duration': '1:45', 'special_train': False, 'train_type': 'MEX', 'score': 25, 'score_train_type': 5, 'score_booking_requency': 0, 'duration_rating': 1, 'score_duration': 10, 'score_std': 10, 'score_user_preferred': 0, 'train_date': '16-12-2023', 'class_type': ['SL', '3A']}, {'train_number': '12401', 'train_name': 'Kota - Dehradun AC SF Express', 'run_days': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'], 'train_src': 'KOTA', 'train_dstn': 'DDN', 'from_std': '23:50', 'from_sta': '23:35', 'local_train_from_sta': 1415, 'to_sta': '01:46', 'to_std': '01:48', 'from_day': 0, 'to_day': 1, 'd_day': 0, 'from': 'NZM', 'to': 'MOZ', 'from_station_name': 'DELHI HAZRAT NIZAMUDDIN', 'halt_stn': 4, 'distance': 125, 'to_station_name': 'MUZAFFARNAGAR', 'duration': '1:56', 'special_train': False, 'train_type': 'SUF', 'score': 25, 'score_train_type': 5, 'score_booking_requency': 0, 'duration_rating': 1, 'score_duration': 10, 'score_std': 10, 'score_user_preferred': 0, 'train_date': '16-12-2023', 'class_type': ['3A', '2A', '1A']}, {'train_number': '18237', 'train_name': 'CHATTISGARH EXP', 'run_days': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'], 'train_src': 'KRBA', 'train_dstn': 'ASR', 'from_std': '20:05', 'from_sta': '19:50', 'local_train_from_sta': 2630, 'to_sta': '22:29', 'to_std': '22:31', 'from_day': 1, 'to_day': 1, 'd_day': 1, 'from': 'NZM', 'to': 'MOZ', 'from_station_name': 'H NIZAMUDDIN', 'halt_stn': 9, 'distance': 126, 'to_station_name': 'MUZAFFARNAGAR', 'duration': '2:24', 'special_train': False, 'train_type': 'MAIL EXPRESS', 'score': 21, 'score_train_type': 5, 'score_booking_requency': 0, 'duration_rating': 2, 'score_duration': 6, 'score_std': 10, 'score_user_preferred': 0, 'train_date': '16-12-2023', 'class_type': ['SL', '3A', '2A', '1A', '3E']}, {'train_number': '22457', 'train_name': 'Vande Bharat Express', 'run_days': ['Mon', 'Tue', 'Thu', 'Fri', 'Sat', 'Sun'], 'train_src': 'ANVT', 'train_dstn': 'DDN', 'from_std': '17:50', 'from_sta': '17:50', 'local_train_from_sta': 1070, 'to_sta': '19:08', 'to_std': '19:10', 'from_day': 0, 'to_day': 0, 'd_day': 0, 'from': 'ANVT', 'to': 'MOZ', 'from_station_name': 'ANAND VIHAR TRM', 'halt_stn': 3, 'distance': 116, 'to_station_name': 'MUZAFFARNAGAR', 'duration': '1:18', 'special_train': False, 'train_type': 'VBEX', 'score': 20, 'score_train_type': 10, 'score_booking_requency': 0, 'duration_rating': 1, 'score_duration': 10, 'score_std': 0, 'score_user_preferred': 0, 'train_date': '16-12-2023', 'class_type': ['CC', 'EC']}, {'train_number': '12055', 'train_name': 'Jan Shatabdi Express', 'run_days': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'], 'train_src': 'NDLS', 'train_dstn': 'DDN', 'from_std': '15:20', 'from_sta': '15:20', 'local_train_from_sta': 920, 'to_sta': '17:12', 'to_std': '17:14', 'from_day': 0, 'to_day': 0, 'd_day': 0, 'from': 'NDLS', 'to': 'MOZ', 'from_station_name': 'NEW DELHI', 'halt_stn': 4, 'distance': 127.7, 'to_station_name': 'MUZAFFARNAGAR', 'duration': '1:52', 'special_train': False, 'train_type': 'JSH', 'score': 15, 'score_train_type': 5, 'score_booking_requency': 0, 'duration_rating': 1, 'score_duration': 10, 'score_std': 0, 'score_user_preferred': 0, 'train_date': '16-12-2023', 'class_type': ['2S', 'CC']}, {'train_number': '12017', 'train_name': 'Shatabdi Express', 'run_days': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'], 'train_src': 'NDLS', 'train_dstn': 'DDN', 'from_std': '06:45', 'from_sta': '06:45', 'local_train_from_sta': 405, 'to_sta': '08:41', 'to_std': '08:43', 'from_day': 0, 'to_day': 0, 'd_day': 0, 'from': 'NDLS', 'to': 'MOZ', 'from_station_name': 'NEW DELHI', 'halt_stn': 4, 'distance': 129, 'to_station_name': 'MUZAFFARNAGAR', 'duration': '1:56', 'special_train': False, 'train_type': 'SHT', 'score': 15, 'score_train_type': 5, 'score_booking_requency': 0, 'duration_rating': 1, 'score_duration': 10, 'score_std': 0, 'score_user_preferred': 0, 'train_date': '16-12-2023', 'class_type': ['CC', 'EC']}, {'train_number': '19019', 'train_name': 'Mumbai Bandra T - Haridwar Express', 'run_days': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'], 'train_src': 'BDTS', 'train_dstn': 'HW', 'from_std': '02:50', 'from_sta': '02:35', 'local_train_from_sta': 1595, 'to_sta': '04:48', 'to_std': '04:50', 'from_day': 1, 'to_day': 1, 'd_day': 1, 'from': 'NZM', 'to': 'MOZ', 'from_station_name': 'DELHI HAZRAT NIZAMUDDIN', 'halt_stn': 4, 'distance': 126, 'to_station_name': 'MUZAFFARNAGAR', 'duration': '1:58', 'special_train': False, 'train_type': 'MEX', 'score': 13, 'score_train_type': 5, 'score_booking_requency': 0, 'duration_rating': 1, 'score_duration': 8, 'score_std': 0, 'score_user_preferred': 0, 'train_date': '16-12-2023', 'class_type': ['SL', '3A', '2A', '1A']}, {'train_number': '19325', 'train_name': 'INDB AMRITSAR EX', 'run_days': ['Wed', 'Sat'], 'train_src': 'INDB', 'train_dstn': 'ASR', 'from_std': '11:40', 'from_sta': '11:25', 'local_train_from_sta': 2125, 'to_sta': '13:43', 'to_std': '13:45', 'from_day': 1, 'to_day': 1, 'd_day': 1, 'from': 'NZM', 'to': 'MOZ', 'from_station_name': 'H NIZAMUDDIN', 'halt_stn': 4, 'distance': 126, 'to_station_name': 'MUZAFFARNAGAR', 'duration': '2:3', 'special_train': False, 'train_type': 'MAIL EXPRESS', 'score': 13, 'score_train_type': 5, 'score_booking_requency': 0, 'duration_rating': 1, 'score_duration': 8, 'score_std': 0, 'score_user_preferred': 0, 'train_date': '16-12-2023', 'class_type': ['SL', '3A', '2A', '1A', '3E']}, {'train_number': '19565', 'train_name': 'OKHA DDN EXP', 'run_days': ['Sat'], 'train_src': 'OKHA', 'train_dstn': 'DDN', 'from_std': '10:40', 'from_sta': '10:25', 'local_train_from_sta': 2065, 'to_sta': '12:44', 'to_std': '12:46', 'from_day': 1, 'to_day': 1, 'd_day': 1, 'from': 'NDLS', 'to': 'MOZ', 'from_station_name': 'NEW DELHI', 'halt_stn': 5, 'distance': 126, 'to_station_name': 'MUZAFFARNAGAR', 'duration': '2:4', 'special_train': False, 'train_type': 'MAIL EXPRESS', 'score': 11, 'score_train_type': 5, 'score_booking_requency': 0, 'duration_rating': 2, 'score_duration': 6, 'score_std': 0, 'score_user_preferred': 0, 'train_date': '16-12-2023', 'class_type': ['SL', '3A', '2A']}, {'train_number': '12903', 'train_name': 'Golden Temple Mail', 'run_days': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'], 'train_src': 'MMCT', 'train_dstn': 'ASR', 'from_std': '14:05', 'from_sta': '13:50', 'local_train_from_sta': 2270, 'to_sta': '16:18', 'to_std': '16:20', 'from_day': 1, 'to_day': 1, 'd_day': 1, 'from': 'NZM', 'to': 'MOZ', 'from_station_name': 'DELHI HAZRAT NIZAMUDDIN', 'halt_stn': 6, 'distance': 126, 'to_station_name': 'MUZAFFARNAGAR', 'duration': '2:13', 'special_train': False, 'train_type': 'SUF', 'score': 11, 'score_train_type': 5, 'score_booking_requency': 0, 'duration_rating': 2, 'score_duration': 6, 'score_std': 0, 'score_user_preferred': 0, 'train_date': '16-12-2023', 'class_type': ['2S', 'SL', '3A', '2A', '1A']}, {'train_number': '14681', 'train_name': 'Intercity Express', 'run_days': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'], 'train_src': 'NDLS', 'train_dstn': 'UMB', 'from_std': '14:45', 'from_sta': '14:45', 'local_train_from_sta': 885, 'to_sta': '16:58', 'to_std': '17:00', 'from_day': 0, 'to_day': 0, 'd_day': 0, 'from': 'NDLS', 'to': 'MOZ', 'from_station_name': 'NEW DELHI', 'halt_stn': 7, 'distance': 129, 'to_station_name': 'MUZAFFARNAGAR', 'duration': '2:13', 'special_train': False, 'train_type': 'INT', 'score': 11, 'score_train_type': 5, 'score_booking_requency': 0, 'duration_rating': 2, 'score_duration': 6, 'score_std': 0, 'score_user_preferred': 0, 'train_date': '16-12-2023', 'class_type': ['2S', 'CC']}, {'train_number': '18477', 'train_name': 'UTKAL EXPRESS', 'run_days': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'], 'train_src': 'PURI', 'train_dstn': 'YNRK', 'from_std': '13:20', 'from_sta': '13:05', 'local_train_from_sta': 3665, 'to_sta': '15:48', 'to_std': '15:50', 'from_day': 2, 'to_day': 2, 'd_day': 2, 'from': 'NZM', 'to': 'MOZ', 'from_station_name': 'H NIZAMUDDIN', 'halt_stn': 6, 'distance': 125, 'to_station_name': 'MUZAFFARNAGAR', 'duration': '2:28', 'special_train': False, 'train_type': 'MAIL EXPRESS', 'score': 11, 'score_train_type': 5, 'score_booking_requency': 0, 'duration_rating': 2, 'score_duration': 6, 'score_std': 0, 'score_user_preferred': 0, 'train_date': '16-12-2023', 'class_type': ['2S', 'SL', '3A', '2A', '3E']}, {'train_number': '14521', 'train_name': 'Intercity Express', 'run_days': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'], 'train_src': 'DLI', 'train_dstn': 'UMB', 'from_std': '13:10', 'from_sta': '13:10', 'local_train_from_sta': 790, 'to_sta': '15:39', 'to_std': '15:44', 'from_day': 0, 'to_day': 0, 'd_day': 0, 'from': 'DLI', 'to': 'MOZ', 'from_station_name': 'OLD DELHI', 'halt_stn': 9, 'distance': 123, 'to_station_name': 'MUZAFFARNAGAR', 'duration': '2:29', 'special_train': False, 'train_type': 'INT', 'score': 11, 'score_train_type': 5, 'score_booking_requency': 0, 'duration_rating': 2, 'score_duration': 6, 'score_std': 0, 'score_user_preferred': 0, 'train_date': '16-12-2023', 'class_type': ['CC']}, {'train_number': '19031', 'train_name': 'YOGA EXPRESS', 'run_days': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'], 'train_src': 'ADI', 'train_dstn': 'YNRK', 'from_std': '04:05', 'from_sta': '04:03', 'local_train_from_sta': 1683, 'to_sta': '07:42', 'to_std': '07:44', 'from_day': 1, 'to_day': 1, 'd_day': 1, 'from': 'DEC', 'to': 'MOZ', 'from_station_name': 'DELHI CANTT', 'halt_stn': 11, 'distance': 136, 'to_station_name': 'MUZAFFARNAGAR', 'duration': '3:37', 'special_train': False, 'train_type': 'MAIL EXPRESS', 'score': 9, 'score_train_type': 5, 'score_booking_requency': 0, 'duration_rating': 4, 'score_duration': 4, 'score_std': 0, 'score_user_preferred': 0, 'train_date': '16-12-2023', 'class_type': ['SL', '3A', '2A', '1A', '3E']}, {'train_number': '14661', 'train_name': 'Barmer - Jammu Tawi Express', 'run_days': ['Mon', 'Wed', 'Sat'], 'train_src': 'BME', 'train_dstn': 'JAT', 'from_std': '15:59', 'from_sta': '15:57', 'local_train_from_sta': 957, 'to_sta': '19:48', 'to_std': '19:50', 'from_day': 0, 'to_day': 0, 'd_day': 0, 'from': 'DEC', 'to': 'MOZ', 'from_station_name': 'DELHI CANTT', 'halt_stn': 12, 'distance': 137, 'to_station_name': 'MUZAFFARNAGAR', 'duration': '3:49', 'special_train': False, 'train_type': 'MEX', 'score': 9, 'score_train_type': 5, 'score_booking_requency': 0, 'duration_rating': 4, 'score_duration': 4, 'score_std': 0, 'score_user_preferred': 0, 'train_date': '16-12-2023', 'class_type': ['SL', '3A', '2A', '1A']}]}
# Out:
# {'status': True,
#  'message': 'Success',
#  'timestamp': 1702731338382,
#  'data': [{'train_number': '14089',
#    'train_name': 'Anand Vihar T - Kotdwar Express',
#    'run_days': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'],
#    'train_src': 'ANVT',
#    'train_dstn': 'KTW',
#    'from_std': '21:45',
#    'from_sta': '21:45',
#    'local_train_from_sta': 1305,
#    'to_sta': '23:30',
#    'to_std': '23:32',
#    'from_day': 0,
#    'to_day': 0,
#    'd_day': 0,
#    'from': 'ANVT',
#    'to': 'MOZ',
#    'from_station_name': 'ANAND VIHAR TRM',
#    'halt_stn': 3,
#    'distance': 116,
#    'to_station_name': 'MUZAFFARNAGAR',
#    'duration': '1:45',
#    'special_train': False,
#    'train_type': 'MEX',
#    'score': 25,
#    'score_train_type': 5,
#    'score_booking_requency': 0,
#    'duration_rating': 1,
#    'score_duration': 10,
#    'score_std': 10,
#    'score_user_preferred': 0,
#    'train_date': '16-12-2023',
#    'class_type': ['SL', '3A']},
# ...

# %%
import json

# %%
with open('data/mytrain.traindatabase.json') as file:
    data=json.loads(file.read())

# %%
data
# Out:
# [{'train_no': '107',
#   'train_name': 'SWV-MAO-VLNK',
#   'seq': '1',
#   'station_code': 'SWV',
#   'station_name': 'SAWANTWADI R',
#   'arrival_time': '00:00:00',
#   'departure time': '10:25:00',
#   'distance': '0',
#   'source_station': 'SWV',
#   'source_station_name': 'SAWANTWADI ROAD',
#   'destination_station': 'MAO',
#   'destination_station_name': 'MADGOAN JN.'},
#  {'train_no': '107',
#   'train_name': 'SWV-MAO-VLNK',
#   'seq': '2',
#   'station_code': 'THVM',
#   'station_name': 'THIVIM',
#   'arrival_time': '11:06:00',
#   'departure time': '11:08:00',
#   'distance': '32',
#   'source_station': 'SWV',
#   'source_station_name': 'SAWANTWADI ROAD',
#   'destination_station': 'MAO',
#   'destination_station_name': 'MADGOAN JN.'},
#  {'train_no': '107',
#   'train_name': 'SWV-MAO-VLNK',
#   'seq': '3',
#   'station_code': 'KRMI',
#   'station_name': 'KARMALI',
#   'arrival_time': '11:28:00',
#   'departure time': '11:30:00',
#   'distance': '49',
# ...

# %%
from pymongo import MongoClient

# %%
client=MongoClient('mongodb+srv://a9756549615:oNOccgAMhlA79wHW@cluster0.mak8f9p.mongodb.net/mytrain?retryWrites=true&w=majority')
mydb=client.mytrain

# %%
try:
    # Attempt to establish a connection
    mydb.db.command('ping')
    print("Connected to MongoDB Atlas successfully!")
except Exception as e:
    print(f"Error connecting to MongoDB Atlas: {e}")
# Out:
# Connected to MongoDB Atlas successfully!

# %%
mydb.traindatabase.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 mydb.traindatabase.insert_many(data)
#
# File c:\Users\a9756\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File c:\Users\a9756\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\collection.py:755, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     753 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     754 blk.ops = list(gen())
# --> 755 blk.execute(write_concern, session=session)
#     756 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# ...

# %%
from tqdm import tqdm

# %%
mydb.traindatabase.insert_many(data)
